# %% [markdown]
# ## Task
#
# Perform Exploratory Data Analysis (EDA) on the data-set given below. Consider Salary as a target variable. You should submit a Jupyter Notebook(i.e. .ipynb file) along with a 5 Page report in Innomatics Report Template. Zip both the files together and upload on LMS.

# %% [markdown]
# **Description:** The dataset was released by Aspiring Minds from the Aspiring Mind Employment Outcome 2015 (AMEO). The study is primarily limited  only to students with engineering disciplines. The dataset contains the employment outcomes of engineering graduates as dependent variables (Salary, Job Titles, and Job Locations) along with the standardized scores from three different areas – cognitive skills, technical skills and personality skills. The dataset also contains demographic features. The dataset  contains  around  40 independent variables and 4000 data points. The independent variables are both continuous and categorical in nature. The dataset contains a unique identifier for each candidate. Below mentioned table contains the details for the original dataset.

# %% [markdown]
# **Objective:** Analize the given dataset and come up with some interesting conclusions or research questions.

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from datetime import datetime as dt
pd.set_option("display.max_columns",None)

# %%
df = pd.read_csv(r"D:\Data_of_AMEO\data.xlsx - Sheet1.csv")

# %%
df.head()
# Out:
#   Unnamed: 0      ID     Salary          DOJ          DOL  \
# 0      train  203097   420000.0  6/1/12 0:00      present
# 1      train  579905   500000.0  9/1/13 0:00      present
# 2      train  810601   325000.0  6/1/14 0:00      present
# 3      train  267447  1100000.0  7/1/11 0:00      present
# 4      train  343523   200000.0  3/1/14 0:00  3/1/15 0:00
#
#                 Designation    JobCity Gender           DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f  2/19/90 0:00          84.3
# 1         assistant manager     Indore      m  10/4/89 0:00          85.4
# 2          systems engineer    Chennai      f   8/3/92 0:00          85.0
# 3  senior software engineer    Gurgaon      m  12/5/89 0:00          85.6
# 4                       get    Manesar      m  2/27/91 0:00          78.0
#
#                           10board  12graduation  12percentage  \
# 0  board ofsecondary education,ap          2007          95.8
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0      ID    Salary           DOJ           DOL  \
# 3993      train   47916  280000.0  10/1/11 0:00  10/1/12 0:00
# 3994      train  752781  100000.0   7/1/13 0:00   7/1/13 0:00
# 3995      train  355888  320000.0   7/1/13 0:00       present
# 3996      train  947111  200000.0   7/1/14 0:00   1/1/15 0:00
# 3997      train  324966  400000.0   2/1/13 0:00       present
#
#                       Designation           JobCity Gender           DOB  \
# 3993            software engineer        New Delhi       m  4/15/87 0:00
# 3994             technical writer         Hyderabad      f  8/27/92 0:00
# 3995  associate software engineer         Bangalore      m   7/3/91 0:00
# 3996           software developer  Asifabadbanglore      f  3/20/92 0:00
# 3997      senior systems engineer           Chennai      f  2/26/91 0:00
#
#       10percentage      10board  12graduation  12percentage      12board  \
# 3993         52.09         cbse          2006         55.50         cbse
# ...

# %%
df.shape
# Out:
# (3998, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3998 non-null   object
#  1   ID                     3998 non-null   int64
#  2   Salary                 3998 non-null   float64
#  3   DOJ                    3998 non-null   object
#  4   DOL                    3998 non-null   object
#  5   Designation            3998 non-null   object
#  6   JobCity                3998 non-null   object
#  7   Gender                 3998 non-null   object
#  8   DOB                    3998 non-null   object
#  9   10percentage           3998 non-null   float64
#  10  10board                3998 non-null   object
#  11  12graduation           3998 non-null   int64
#  12  12percentage           3998 non-null   float64
#  13  12board                3998 non-null   object
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0                  1
# ID                       3998
# Salary                    177
# DOJ                        81
# DOL                        67
# Designation               419
# JobCity                   339
# Gender                      2
# DOB                      1872
# 10percentage              851
# 10board                   275
# 12graduation               16
# 12percentage              801
# 12board                   340
# CollegeID                1350
# CollegeTier                 2
# Degree                      4
# Specialization             46
# collegeGPA               1282
# CollegeCityID            1350
# CollegeCityTier             2
# CollegeState               26
# GraduationYear             11
# English                   111
# Logical                   107
# Quant                     138
# Domain                    243
# ComputerProgramming        79
# ElectronicsAndSemicon      29
# ComputerScience            20
# MechanicalEngg             42
# ...

# %%
df.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %% [markdown]
# **Data Cleaning:**
# 1. Removing the Garbage Columns.
# 2. Converting columns into it's appropriate type.
# 3. Mapping specialization column with CS,EC,ME,El,Other.

# %%
specialization_map = \
{'electronics and communication engineering' : 'EC',
 'computer science & engineering' : 'CS',
 'information technology' : 'CS' ,
 'computer engineering' : 'CS',
 'computer application' : 'CS',
 'mechanical engineering' : 'ME',
 'electronics and electrical engineering' : 'EC',
 'electronics & telecommunications' : 'EC',
 'electrical engineering' : 'EL',
 'electronics & instrumentation eng' : 'EC',
 'civil engineering' : 'CE',
 'electronics and instrumentation engineering' : 'EC',
 'information science engineering' : 'CS',
 'instrumentation and control engineering' : 'EC',
 'electronics engineering' : 'EC',
 'biotechnology' : 'other',
 'other' : 'other',
 'industrial & production engineering' : 'other',
 'chemical engineering' : 'other',
 'applied electronics and instrumentation' : 'EC',
 'computer science and technology' : 'CS',
 'telecommunication engineering' : 'EC',
 'mechanical and automation' : 'ME',
 'automobile/automotive engineering' : 'ME',
 'instrumentation engineering' : 'EC',
 'mechatronics' : 'ME',
 'electronics and computer engineering' : 'CS',
 'aeronautical engineering' : 'ME',
 'computer science' : 'CS',
 'metallurgical engineering' : 'other',
 'biomedical engineering' : 'other',
 'industrial engineering' : 'other',
 'information & communication technology' : 'EC',
 'electrical and power engineering' : 'EL',
 'industrial & management engineering' : 'other',
 'computer networking' : 'CS',
 'embedded systems technology' : 'EC',
 'power systems and automation' : 'EL',
 'computer and communication engineering' : 'CS',
 'information science' : 'CS',
 'internal combustion engine' : 'ME',
 'ceramic engineering' : 'other',
 'mechanical & production engineering' : 'ME',
 'control and instrumentation engineering' : 'EC',
 'polymer technology' : 'other',
 'electronics' : 'EC'}

# %%
df['Specialization'] = df['Specialization'].map(specialization_map)
df['Specialization'].unique()
# Out:
# array(['CS', 'EC', 'ME', 'EL', 'CE', 'other'], dtype=object)

# %%
df["Specialization"].value_counts()
# Out:
# CS       2289
# EC       1319
# ME        220
# EL         85
# other      56
# CE         29
# Name: Specialization, dtype: int64

# %%
df.drop(["Unnamed: 0","ID","CollegeID","CollegeCityID"], axis = 1, inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender', 'DOB',
#        '10percentage', '10board', '12graduation', '12percentage', '12board',
#        'CollegeTier', 'Degree', 'Specialization', 'collegeGPA',
#        'CollegeCityTier', 'CollegeState', 'GraduationYear', 'English',
#        'Logical', 'Quant', 'Domain', 'ComputerProgramming',
#        'ElectronicsAndSemicon', 'ComputerScience', 'MechanicalEngg',
#        'ElectricalEngg', 'TelecomEngg', 'CivilEngg', 'conscientiousness',
#        'agreeableness', 'extraversion', 'nueroticism',
#        'openess_to_experience'],
#       dtype='object')

# %%
df["CollegeCityTier"] = df["CollegeCityTier"].astype(str)
df["12graduation"] = df["12graduation"].astype(str)
df["GraduationYear"] = df["GraduationYear"].astype(str)
df["CollegeTier"] = df["CollegeTier"].astype(str)

# %%
df["DOJ"] = df["DOJ"].str.replace("0:00","")
df["DOB"] = df["DOB"].str.replace("0:00","")
df["DOL"] = df["DOL"].str.replace("0:00","")

# %% [markdown]
# #### Converting collegegpa into floating point on a scale of 10 and rounding of to two decimals.

# %%
df["collegeGPA"] = round(df["collegeGPA"] / 10 ,2)

# %% [markdown]
# #### Converting DOL, DOJ and DOL into Datetime type.

# %%
today_date = dt.now().strftime('%Y-%m-%d')

# %%
df["DOL"] = df["DOL"].replace("present",today_date)

# %%
df[["DOJ","DOB","DOL"]] = df[["DOJ","DOB","DOL"]].apply(pd.to_datetime)

# %% [markdown]
# #### Selecting only numerical columns.

# %%
continous_columns = df[["Salary","10percentage","12percentage","collegeGPA"]]

# %% [markdown]
# #### Selecting only object columns.

# %%
categorical_columns = df.select_dtypes(["object"])

# %% [markdown]
# #### Selecting only subject scores

# %%
subject_scores = df[["English","Logical","Quant","Domain","ComputerProgramming",
                     "ElectronicsAndSemicon","ComputerScience","MechanicalEngg","ElectricalEngg",
                     "TelecomEngg","CivilEngg","conscientiousness","agreeableness","extraversion",
                     "nueroticism","openess_to_experience"]]

# %% [markdown]
# #### Checking all the datatypes of the colunms.

# %%
df.dtypes
# Out:
# Salary                          float64
# DOJ                      datetime64[ns]
# DOL                      datetime64[ns]
# Designation                      object
# JobCity                          object
# Gender                           object
# DOB                      datetime64[ns]
# 10percentage                    float64
# 10board                          object
# 12graduation                     object
# 12percentage                    float64
# 12board                          object
# CollegeTier                      object
# Degree                           object
# Specialization                   object
# collegeGPA                      float64
# CollegeCityTier                  object
# CollegeState                     object
# GraduationYear                   object
# English                           int64
# Logical                           int64
# Quant                             int64
# Domain                          float64
# ...

# %% [markdown]
# **Note:** In this DataFrame contains missing values in the "Designation" column, indicated by "get." Additionally, missing values in the "JobCity" column are represented by "-1," while in the "10board" and "12board" column, they are denoted by "0." These abnormalities need to be addressed and handled appropriately.

# %%
replace_value1 = next((city for city in df['JobCity'] if city != '-1'), None)
df['JobCity'] = df['JobCity'].replace('-1', replace_value1)

# %%
replace_value2 = next((city for city in df['Designation'] if city != 'get'), None)
df['Designation'] = df['Designation'].replace('get', replace_value2)

# %%
replace_value3 = next((city for city in df['10board'] if city != '0'), None)
df['10board'] = df['10board'].replace('0', replace_value3)

# %%
replace_value4 = next((city for city in df['12board'] if city != '0'), None)
df['12board'] = df['12board'].replace('0', replace_value4)

# %% [markdown]
# ## Univariate Analysis (Non - Visualization)

# %%
for column in continous_columns:
    print("*"*10, column , "*"*10)
    print(continous_columns[column].agg(["min","max","mean","median","std","kurt"]))
    print()
# Out:
# ********** Salary **********
# min       3.500000e+04
# max       4.000000e+06
# mean      3.076998e+05
# median    3.000000e+05
# std       2.127375e+05
# kurt      8.093000e+01
# Name: Salary, dtype: float64
#
# ********** 10percentage **********
# min       43.000000
# max       97.760000
# mean      77.925443
# median    79.150000
# std        9.850162
# kurt      -0.110284
# Name: 10percentage, dtype: float64
#
# ********** 12percentage **********
# min       40.000000
# max       98.700000
# mean      74.466366
# median    74.400000
# std       10.999933
# kurt      -0.630737
# Name: 12percentage, dtype: float64
#
# ********** collegeGPA **********
# min        0.640000
# max        9.990000
# mean       7.148617
# median     7.170000
# std        0.816767
# kurt      10.232088
# Name: collegeGPA, dtype: float64

# %%
for column in subject_scores:
    print("*"*10, column , "*"*10)
    print(subject_scores[column].agg(["min","max","mean","median","std","kurt"]))
    print()
# Out:
# ********** English **********
# min       180.000000
# max       875.000000
# mean      501.649075
# median    500.000000
# std       104.940021
# kurt       -0.254133
# Name: English, dtype: float64
#
# ********** Logical **********
# min       195.000000
# max       795.000000
# mean      501.598799
# median    505.000000
# std        86.783297
# kurt       -0.224761
# Name: Logical, dtype: float64
#
# ********** Quant **********
# min       120.000000
# max       900.000000
# mean      513.378189
# median    515.000000
# std       122.302332
# kurt       -0.102472
# Name: Quant, dtype: float64
#
# ********** Domain **********
# min      -1.000000
# max       0.999910
# mean      0.510490
# median    0.622643
# std       0.468671
# kurt      3.895951
# Name: Domain, dtype: float64
#
# ********** ComputerProgramming **********
# min        -1.000000
# max       840.000000
# mean      353.102801
# median    415.000000
# std       205.355519
# kurt       -0.666352
# ...

# %%
for column in categorical_columns:
    print("*"*10, column , "*"*10)
    print(categorical_columns[column].agg(["count","nunique","unique"]))
    print("Value Counts: \n",categorical_columns[column].value_counts())
    print()
# Out:
# ********** Designation **********
# count                                                   3998
# nunique                                                  419
# unique     [senior quality engineer, assistant manager, s...
# Name: Designation, dtype: object
# Value Counts:
#  software engineer                    539
# software developer                   265
# system engineer                      205
# programmer analyst                   139
# systems engineer                     118
#                                     ...
# cad drafter                            1
# noc engineer                           1
# human resources intern                 1
# senior quality assurance engineer      1
# jr. software developer                 1
# Name: Designation, Length: 419, dtype: int64
#
# ********** JobCity **********
# count                                                   3998
# nunique                                                  339
# ...

# %% [markdown]
# ## Univariate Analysis (Visualization)

# %%
continous_columns
# Out:
#          Salary  10percentage  12percentage  collegeGPA
# 0      420000.0         84.30         95.80        7.80
# 1      500000.0         85.40         85.00        7.01
# 2      325000.0         85.00         68.20        7.00
# 3     1100000.0         85.60         83.60        7.46
# 4      200000.0         78.00         76.80        7.39
# ...         ...           ...           ...         ...
# 3993   280000.0         52.09         55.50        6.15
# 3994   100000.0         90.00         93.00        7.73
# 3995   320000.0         81.86         65.50        7.00
# 3996   200000.0         78.72         69.88        7.04
# 3997   400000.0         70.60         68.00        6.80
#
# [3998 rows x 4 columns]

# %%
df.hist(column=["Salary", "10percentage", "12percentage", "collegeGPA"])
# Out:
# array([[<AxesSubplot:title={'center':'Salary'}>,
#         <AxesSubplot:title={'center':'10percentage'}>],
#        [<AxesSubplot:title={'center':'12percentage'}>,
#         <AxesSubplot:title={'center':'collegeGPA'}>]], dtype=object)

# %%
df.hist(column=["English","Logical","Quant","Domain","ComputerProgramming",
                     "ElectronicsAndSemicon","ComputerScience","MechanicalEngg"])
plt.tight_layout()
plt.show()

# %%
df.hist(column=["ElectricalEngg","TelecomEngg","CivilEngg","conscientiousness","agreeableness",
                "extraversion","nueroticism","openess_to_experience"])
plt.tight_layout()
plt.show()

# %%
for col in continous_columns:
    plt.figure(figsize=(4, 3))
    sns.kdeplot(df[col], label=col, shade=True)
    plt.xlabel('Values')
    plt.ylabel('Density')
    plt.title(f'KDE Plot for {col}')
    plt.legend(fontsize='small')
    plt.tight_layout() 
    plt.show()

# %%
for col in subject_scores:
    plt.figure(figsize=(4, 3))
    sns.kdeplot(df[col], label=col, shade=True)
    plt.xlabel('Values')
    plt.ylabel('Density')
    plt.title(f'KDE Plot for {col}')
    plt.legend(fontsize='small')
    plt.tight_layout() 
    plt.show()

# %%
for col in continous_columns:
    plt.figure(figsize=(4, 3))
    sns.boxplot(y = col, data = df)
    plt.xlabel('Values')
    plt.ylabel('Density')
    plt.title(f'Boxplot for {col}')
    plt.tight_layout() 
    plt.show()

# %%
for col in subject_scores:
    plt.figure(figsize=(4, 3))
    sns.boxplot(y = col, data = df)
    plt.xlabel('Values')
    plt.ylabel('Density')
    plt.title(f'Boxplot for {col}')
    plt.tight_layout() 
    plt.show()

# %%
for column in categorical_columns:
    top_categories = df[column].value_counts().head(5)
    # Barplot
    sns.barplot(y = top_categories.index,x = top_categories.values, data = df)
    plt.xlabel("Count")
    plt.ylabel(column)
    plt.xticks(rotation = None)
    plt.title(f"Countplot of {column}")
    plt.show()

# %% [markdown]
# ## Bivariate Analysis (Non - Visualization)

# %%
df.corr()
# Out:
#                          Salary  10percentage  12percentage  collegeGPA  \
# Salary                 1.000000      0.177373      0.170254    0.130089
# 10percentage           0.177373      1.000000      0.643378    0.312579
# 12percentage           0.170254      0.643378      1.000000    0.346216
# collegeGPA             0.130089      0.312579      0.346216    1.000000
# English                0.178219      0.350780      0.212888    0.106433
# Logical                0.179275      0.316014      0.243571    0.196548
# Quant                  0.230627      0.317640      0.312413    0.217322
# Domain                 0.104656      0.078563      0.074099    0.107229
# ComputerProgramming    0.115665      0.053600      0.080818    0.136556
# ElectronicsAndSemicon  0.000665      0.085179      0.117112    0.029882
# ComputerScience       -0.100720     -0.018933     -0.043534    0.007581
# MechanicalEngg         0.018475      0.050364      0.037635   -0.031768
# ...

# %%
grouped_df1 = df.groupby("Designation")["Salary"].mean()[:5]

# %%
grouped_df1
# Out:
# Designation
# .net developer        223382.352941
# .net web developer    196250.000000
# account executive     287500.000000
# account manager       350000.000000
# admin assistant       102500.000000
# Name: Salary, dtype: float64

# %%
grouped_df2 = df.groupby("Specialization")["Salary"].mean()[:5]

# %%
grouped_df2
# Out:
# Specialization
# CE    381206.896552
# CS    312020.532984
# EC    298798.332070
# EL    289529.411765
# ME    310836.363636
# Name: Salary, dtype: float64

# %%
df[['10percentage', '12percentage', 'collegeGPA', 'Gender']].groupby('Gender').mean()
# Out:
#         10percentage  12percentage  collegeGPA
# Gender
# f          80.932894     77.007618    7.404838
# m          76.979000     73.666636    7.067984

# %%
print(df[['Salary', 'Gender']].groupby("Gender").max())
print(df[['Salary', 'Gender']].groupby('Gender').min())
# Out:
#            Salary
# Gender
# f       3500000.0
# m       4000000.0
#          Salary
# Gender
# f       35000.0
# m       35000.0

# %%
pivot1 = df.pivot_table(index = "JobCity", columns = "Gender", values = "Salary", aggfunc = "mean")

# %%
pivot1.head(10)
# Out:
# Gender                    f         m
# JobCity
#  Chennai                NaN  335000.0
#  Delhi                  NaN  360000.0
#  Mumbai                 NaN  145000.0
#  Pune                   NaN  180000.0
#  ariyalur               NaN  570000.0
#  bangalore         560000.0       NaN
#  mumbai                 NaN  265000.0
# A-64,sec-64,noida       NaN  120000.0
# AM                      NaN  360000.0
# Agra                    NaN  150000.0

# %%
pivot2 = df.pivot_table(index = "Degree", columns = "Gender", values = "collegeGPA", aggfunc = "mean")

# %%
pivot2
# Out:
# Gender                f         m
# Degree
# B.Tech/B.E.    7.378414  7.049303
# M.Sc. (Tech.)  7.000000  8.120000
# M.Tech./M.E.   8.630000  7.308864
# MCA            7.626724  7.288865

# %%
crosstab1 = pd.crosstab(df["Gender"],df["Degree"])

# %%
crosstab1
# Out:
# Degree  B.Tech/B.E.  M.Sc. (Tech.)  M.Tech./M.E.  MCA
# Gender
# f               889              1             9   58
# m              2811              1            44  185

# %%
crosstab2 = pd.crosstab(df["Gender"],df["GraduationYear"])

# %%
crosstab2
# Out:
# GraduationYear  0  2007  2009  2010  2011  2012  2013  2014  2015  2016  2017
# Gender
# f               0     0     6    54   133   227   278   242    15     1     1
# m               1     1    18   238   374   620   903   794    79     6     7

# %%
crosstab3 = pd.crosstab(df["Degree"],df["CollegeState"])

# %%
crosstab3
# Out:
# CollegeState   Andhra Pradesh  Assam  Bihar  Chhattisgarh  Delhi  Goa  \
# Degree
# B.Tech/B.E.               209      5     10            25    145    1
# M.Sc. (Tech.)               0      0      0             0      0    0
# M.Tech./M.E.                3      0      0             1      0    0
# MCA                        13      0      0             1     17    0
#
# CollegeState   Gujarat  Haryana  Himachal Pradesh  Jammu and Kashmir  \
# Degree
# B.Tech/B.E.         21      176                16                  6
# M.Sc. (Tech.)        1        0                 0                  0
# M.Tech./M.E.         2        1                 0                  0
# MCA                  0        3                 0                  1
#
# CollegeState   Jharkhand  Karnataka  Kerala  Madhya Pradesh  Maharashtra  \
# Degree
# B.Tech/B.E.           22        339      31             176          236
# M.Sc. (Tech.)          0          0       0               0            0
# ...

# %%
crosstab4 = pd.crosstab(df["Specialization"],df["Gender"])

# %%
crosstab4
# Out:
# Gender            f     m
# Specialization
# CE                6    23
# CS              601  1688
# EC              306  1013
# EL               17    68
# ME               12   208
# other            15    41

# %% [markdown]
# ## Bivariate Analysis (Visualization)

# %%
df.head()
# Out:
#       Salary        DOJ        DOL               Designation    JobCity  \
# 0   420000.0 2012-06-01 2024-03-10   senior quality engineer  Bangalore
# 1   500000.0 2013-09-01 2024-03-10         assistant manager     Indore
# 2   325000.0 2014-06-01 2024-03-10          systems engineer    Chennai
# 3  1100000.0 2011-07-01 2024-03-10  senior software engineer    Gurgaon
# 4   200000.0 2014-03-01 2015-03-01   senior quality engineer    Manesar
#
#   Gender        DOB  10percentage                         10board  \
# 0      f 1990-02-19          84.3  board ofsecondary education,ap
# 1      m 1989-10-04          85.4                            cbse
# 2      f 1992-08-03          85.0                            cbse
# 3      m 1989-12-05          85.6                            cbse
# 4      m 1991-02-27          78.0                            cbse
#
#   12graduation  12percentage                             12board CollegeTier  \
# ...

# %%
sns.pairplot(df[["10percentage","12percentage","collegeGPA"]])

# %%
correlation_matrix = subject_scores.corr()

# %%
plt.figure(figsize = (8,6))
sns.heatmap(correlation_matrix, annot = True, cmap = "coolwarm",fmt = ".2f",annot_kws = {"size":7})
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
popular_Designation = df['Designation'].value_counts()[:15].index.tolist()
top_Designations = df[df['Designation'].isin(popular_Designation)]

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Designation',hue='Gender',data=top_Designations)
plt.xticks(fontsize=20,rotation=70)
plt.yticks(fontsize=20)
plt.show()

# %%
top_5_designations = df.nlargest(10, 'Salary')

# %%
colors = ['skyblue', 'orange', 'green', 'red', 'purple']

# %%
plt.figure(figsize=(12, 6))
plt.bar(top_5_designations['Designation'], top_5_designations['Salary'],color = colors)
plt.xlabel('Designation')
plt.ylabel('Salary')
plt.title('Designation vs Salary')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df.head(20)
# Out:
#        Salary        DOJ        DOL                   Designation    JobCity  \
# 0    420000.0 2012-06-01 2024-03-10       senior quality engineer  Bangalore
# 1    500000.0 2013-09-01 2024-03-10             assistant manager     Indore
# 2    325000.0 2014-06-01 2024-03-10              systems engineer    Chennai
# 3   1100000.0 2011-07-01 2024-03-10      senior software engineer    Gurgaon
# 4    200000.0 2014-03-01 2015-03-01       senior quality engineer    Manesar
# 5    300000.0 2014-06-01 2024-03-10               system engineer  Hyderabad
# 6    300000.0 2014-08-01 2015-05-01        java software engineer   Banglore
# 7    400000.0 2014-07-01 2015-07-01           mechanical engineer  Bangalore
# 8    600000.0 2013-07-01 2024-03-10           electrical engineer      Noida
# 9    230000.0 2014-07-01 2024-03-10              project engineer    Kolkata
# 10   600000.0 2011-04-01 2015-04-01          senior php developer  Bangalore
# ...

# %%
plt.figure(figsize=(15,5))
colors = sns.color_palette('bright',n_colors=2)
sns.FacetGrid(df, col="Gender", size=5,palette=colors) \
   .map(sns.distplot, "Salary",bins=50) \
   .add_legend()
plt.show()
# Out:
# C:\Users\Yashas\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Yashas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Yashas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 5))
colors = sns.color_palette('bright', n_colors=2)
sns.FacetGrid(df, col="Gender", height=5, palette=colors) \
   .map(sns.distplot, "Salary", bins=50) \
   .add_legend()
plt.xlim(0, 700000)  
plt.show()
# Out:
# C:\Users\Yashas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Yashas\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
specified_roles = ['programmer analyst', 'software engineer', 'Hardware Engineer','Associate Engineer','software developer',
                  'jr. software developer','programmer','java software engineer']



threshold = 1200000
specified_df = df[(df['Designation'].isin(specified_roles)) & (df['Salary'] <= threshold)]

plt.figure(figsize=(8, 5))
sns.histplot(specified_df['Salary'], kde=True, color='skyblue')
plt.axvline(x=250000, color='r', linestyle='--', label='Lower Bound (2.5 Lakhs)')
plt.axvline(x=320000, color='g', linestyle='--', label='Upper Bound (3.2 Lakhs)')
plt.xlabel('Salary')
plt.ylabel('Density')
plt.title('Distribution of Salaries for Computer Science Engineering')
plt.legend()

plt.gca().xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.grid(axis='y', alpha=0.75)
plt.tight_layout()
plt.show()

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['Gender'], df['Specialization'])

chi2, p, dof, expected = chi2_contingency(contingency_table)

print("Chi-square statistic:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)

alpha = 0.05 
if p < alpha:
    print("There is a significant relationship between Gender and Specialization.")
else:
    print("There is no significant relationship between Gender and Specialization.")
# Out:
# Chi-square statistic: 49.57240850719073
# p-value: 1.6950209831469834e-09
# Degrees of freedom: 5
# There is a significant relationship between Gender and Specialization.
